# %%
import typesense
import os

# %%
print(os.getenv('TYPESENSE_API_KEY'))
# Out:
# ABb9herQ8K4nREoVKYicAP84KHCGUJSd

# %%
client=typesense.Client({
    'nodes':[{
        'host':'rgom6cwhp0bdylsep-1.a2.typesense.net',
        'port':'443',
        'protocol':'https'
    }],
    'api_key':os.getenv('TYPESENSE_API_KEY'),
    'connection_timeout_seconds':2
})

# %%
client

# %%
books_schema = {
  'name': 'books',
  'fields': [
    {'name': 'title', 'type': 'string' },
    {'name': 'authors', 'type': 'string[]', 'facet': True },

    {'name': 'publication_year', 'type': 'int32', 'facet': True }, #facet:- for ex when we search 'phone' we want filters like apple,samsung, that is done using facet
    {'name': 'ratings_count', 'type': 'int32' },
    {'name': 'average_rating', 'type': 'float' }
  ],
  'default_sorting_field': 'ratings_count'
}

# %%
# client.collections.create(books_schema)
# Out:
# ---------------------------------------------------------------------------
# ObjectAlreadyExists                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 client.collections.create(books_schema)
#
# File d:\RAG_PRACTICE\venv\Lib\site-packages\typesense\sync\collections.py:136, in Collections.create(self, schema)
#     111 def create(self, schema: CollectionCreateSchema) -> CollectionSchema:
#     112     """
#     113     Create a new collection in Typesense.
#     114
#    (...)    134         >>> created_schema = await collections.create(schema)
#     135     """
# --> 136     call: CollectionSchema = self.api_call.post(
#     137         endpoint=Collections.resource_path,
#     138         entity_type=CollectionSchema,
#     139         as_json=True,
#     140         body=schema,
#     141     )
#     142     return call
#
# ...

# %%
with open('/tmp/books.jsonl',encoding='utf-8') as jsonl_file:
  client.collections['books'].documents.import_(jsonl_file.read().encode('utf-8'))

# %%
search_parameters={
    'q':'harry potter',
    'query_by':'title',
    'sort_by':'ratings_count:desc'
}
client.collections['books'].documents.search(search_parameters)
# Out:
# {'facet_counts': [],
#  'found': 17,
#  'hits': [{'document': {'authors': ['J.K. Rowling', ' Mary GrandPré'],
#     'average_rating': 4.44,
#     'id': '2',
#     'image_url': 'https://images.gr-assets.com/books/1474154022m/3.jpg',
#     'publication_year': 1997,
#     'ratings_count': 4602479,
#     'title': "Harry Potter and the Philosopher's Stone"},
#    'highlight': {'title': {'matched_tokens': ['Harry', 'Potter'],
#      'snippet': "<mark>Harry</mark> <mark>Potter</mark> and the Philosopher's Stone"}},
#    'highlights': [{'field': 'title',
#      'matched_tokens': ['Harry', 'Potter'],
#      'snippet': "<mark>Harry</mark> <mark>Potter</mark> and the Philosopher's Stone"}],
#    'text_match': 1157451471441102969,
#    'text_match_info': {'best_field_score': '2211897868289',
#     'best_field_weight': 15,
#     'fields_matched': 1,
#     'num_tokens_dropped': 0,
#     'score': '1157451471441102969',
#     'tokens_matched': 2,
#     'typo_prefix_score': 0}},
# ...

# %%
search_parameters={
    'q':'harry potter',
    'query_by':'title',
    'sort_by':'ratings_count:desc',
    'filter_by':'publication_year:<1998'
}
client.collections['books'].documents.search(search_parameters)
# Out:
# {'facet_counts': [],
#  'found': 1,
#  'hits': [{'document': {'authors': ['J.K. Rowling', ' Mary GrandPré'],
#     'average_rating': 4.44,
#     'id': '2',
#     'image_url': 'https://images.gr-assets.com/books/1474154022m/3.jpg',
#     'publication_year': 1997,
#     'ratings_count': 4602479,
#     'title': "Harry Potter and the Philosopher's Stone"},
#    'highlight': {'title': {'matched_tokens': ['Harry', 'Potter'],
#      'snippet': "<mark>Harry</mark> <mark>Potter</mark> and the Philosopher's Stone"}},
#    'highlights': [{'field': 'title',
#      'matched_tokens': ['Harry', 'Potter'],
#      'snippet': "<mark>Harry</mark> <mark>Potter</mark> and the Philosopher's Stone"}],
#    'text_match': 1157451471441102969,
#    'text_match_info': {'best_field_score': '2211897868289',
#     'best_field_weight': 15,
#     'fields_matched': 1,
#     'num_tokens_dropped': 0,
#     'score': '1157451471441102969',
#     'tokens_matched': 2,
#     'typo_prefix_score': 0}}],
#  'out_of': 9979,
# ...

# %%
search_parameters={
    'q':'harry potter',
    'query_by':'title',
    'sort_by':'ratings_count:desc',
    'facet_by':'authors'
}
client.collections['books'].documents.search(search_parameters)
# Out:
# {'facet_counts': [{'counts': [{'count': 10,
#      'highlighted': 'J.K. Rowling',
#      'value': 'J.K. Rowling'},
#     {'count': 8, 'highlighted': ' Mary GrandPré', 'value': ' Mary GrandPré'},
#     {'count': 2, 'highlighted': ' J.K. Rowling', 'value': ' J.K. Rowling'},
#     {'count': 1, 'highlighted': 'Bob McCabe', 'value': 'Bob McCabe'},
#     {'count': 1, 'highlighted': 'Brian Sibley', 'value': 'Brian Sibley'},
#     {'count': 1, 'highlighted': 'David Colbert', 'value': 'David Colbert'},
#     {'count': 1, 'highlighted': 'David Baggett', 'value': 'David Baggett'},
#     {'count': 1, 'highlighted': 'Melissa Anelli', 'value': 'Melissa Anelli'},
#     {'count': 1, 'highlighted': 'John   Williams', 'value': 'John   Williams'},
#     {'count': 1,
#      'highlighted': ' Shawn E. Klein',
#      'value': ' Shawn E. Klein'}],
#    'field_name': 'authors',
#    'sampled': False,
#    'stats': {'total_values': 13}}],
#  'found': 17,
# ...
